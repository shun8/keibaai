# %% [markdown]
# ### Import

# %%
from sqlalchemy import create_engine
import os
import yaml
from pathlib import Path

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Config

# %%
base = Path().resolve()
db_conf_file = os.path.normpath(os.path.join(base, "../conf/db_connection.yaml"))
with open(db_conf_file, "r", encoding="utf-8") as l_file:
    db_conf_all = yaml.safe_load(l_file)

# %% [markdown]
# ### Create Engine

# %%
ora_conf = db_conf_all["oracle"]
engine = create_engine(f"oracle://{ora_conf['username']}:{ora_conf['password']}@{ora_conf['dsn']}/?encoding=UTF-8&nencoding=UTF-8")

# %% [markdown]
# ### Condition

# %%
c_cource_id = "06_t1200_out"

# %% [markdown]
# ### Query

# %%
from sqlalchemy.sql import select
from sqlalchemy.sql import join

from model.race import Race
from keibaai.model.race import RaceUma

query_statement = (
    select(
        join(Race, RaceUma, Race.id == RaceUma.race_id)
        ).where(
            Race.course_id == c_cource_id
        )
)
print(query_statement)
# Out:
# SELECT races.id, races.name, races.race_track_id, races.kai, races.nichi, races.race_no, races.course_id, races.grade_id, races.is_win5, races.condition, races.handicap, races.race_date, races.race_start, races.weather, races.going, races.num_of_horses, races.race_data, races.corner_order_1, races.corner_order_2, races.corner_order_3, races.corner_order_4, races.pace, race_uma.race_id, race_uma.uma_id, race_uma.result, race_uma.bracket_number, race_uma.horse_number, race_uma.gender, race_uma.age, race_uma.weight_to_carry, race_uma.jockey_id, race_uma.time, race_uma.margin, race_uma.ninki, race_uma.win_odds, race_uma.final_3_furlong, race_uma.corner_order, race_uma.trainer_id, race_uma.horse_weight, race_uma.gain_and_loss_weight, race_uma.is_excluded, race_uma.is_demoted
# FROM races JOIN race_uma ON races.id = race_uma.race_id
# WHERE races.course_id = :course_id_1

# %%
query_statement = (
    select(
        Race.race_track_id, Race.kai, Race.nichi, Race.race_no, Race.grade_id, Race.num_of_horses, RaceUma.result, RaceUma.bracket_number, RaceUma.horse_number, RaceUma.age, RaceUma.weight_to_carry, RaceUma.time, RaceUma.ninki, RaceUma.win_odds, RaceUma.final_3_furlong, RaceUma.horse_weight, RaceUma.gain_and_loss_weight
    ).select_from(
        join(Race, RaceUma, Race.id == RaceUma.race_id)
    ).where(
        Race.course_id == c_cource_id
    )
)
print(query_statement)
# Out:
# SELECT races.race_track_id, races.kai, races.nichi, races.race_no, races.grade_id, races.num_of_horses, race_uma.result, race_uma.bracket_number, race_uma.horse_number, race_uma.age, race_uma.weight_to_carry, race_uma.time, race_uma.ninki, race_uma.win_odds, race_uma.final_3_furlong, race_uma.horse_weight, race_uma.gain_and_loss_weight
# FROM races JOIN race_uma ON races.id = race_uma.race_id
# WHERE races.course_id = :course_id_1

# %% [markdown]
# ### Read Data

# %%
data = pd.read_sql_query(sql=query_statement, con=engine)
data
# Out:
#       race_track_id  kai  nichi  race_no  grade_id  num_of_horses  result  \
# 0                60   50     20        9        16             15     1.0
# 1                60   50     20        9        16             15     2.0
# 2                60   50     20        9        16             15     3.0
# 3                60   50     20        9        16             15     4.0
# 4                60   50     20        9        16             15     5.0
# ...             ...  ...    ...      ...       ...            ...     ...
# 3353             60   30     20        6         9             13     9.0
# 3354             60   30     20        6         9             13    10.0
# 3355             60   30     20        6         9             13    11.0
# 3356             60   30     20        6         9             13    12.0
# 3357             60   30     20        6         9             13    13.0
#
#       bracket_number  horse_number  age  weight_to_carry  time  ninki  \
# 0                  5             9    3             56.0  67.4      6
# 1                  3             5    3             54.0  67.6      1
# 2                  6            11    4             57.0  67.8      2
# 3                  5             8    5             57.0  67.9      3
# 4                  2             2    6             55.0  67.9      8
# ...              ...           ...  ...              ...   ...    ...
# 3353               4             4    3             56.0  71.5     10
# 3354               5             7    3             54.0  71.9     12
# 3355               4             5    3             51.0  71.9     11
# 3356               1             1    3             51.0  72.1     13
# 3357               8            13    3             54.0  72.2      8
#
#       win_odds  final_3_furlong  horse_weight  gain_and_loss_weight
# 0         10.7             33.8           468                     8
# 1          2.8             34.3           470                     0
# 2          4.6             34.0           496                     2
# 3          7.2             34.5           540                     2
# 4         17.3             34.1           518                     4
# ...        ...              ...           ...                   ...
# 3353      57.6             36.3           446                     8
# 3354     151.1             37.0           462                     4
# 3355     104.1             36.9           430                    -2
# 3356     260.6             36.5           408                     4
# 3357      25.7             38.1           404                     2
#
# [3358 rows x 17 columns]

# %% [markdown]
# ### Describe

# %%
data.describe()
# Out:
#        race_track_id          kai        nichi      race_no     grade_id  \
# count         3358.0  3358.000000  3358.000000  3358.000000  3358.000000
# mean            60.0    34.142347    48.412448     3.348422    15.727516
# std              0.0    13.010845    24.569488     2.995198     9.848203
# min             60.0    10.000000    10.000000     0.000000     1.000000
# 25%             60.0    20.000000    30.000000     1.000000     7.000000
# 50%             60.0    40.000000    50.000000     2.000000    16.000000
# 75%             60.0    40.000000    70.000000     6.000000    30.000000
# max             60.0    50.000000    91.000000     9.000000    31.000000
#
#        num_of_horses       result  bracket_number  horse_number          age  \
# count    3358.000000  3350.000000     3358.000000   3358.000000  3358.000000
# mean       15.212031     8.088657        4.624777      8.106015     3.867778
# std         1.577039     4.470689        2.273470      4.476073     1.783091
# min         8.000000     1.000000        1.000000      1.000000     2.000000
# 25%        15.000000     4.000000        3.000000      4.000000     2.000000
# 50%        16.000000     8.000000        5.000000      8.000000     4.000000
# 75%        16.000000    12.000000        7.000000     12.000000     5.000000
# max        16.000000    16.000000        8.000000     16.000000    11.000000
#
#        weight_to_carry         time        ninki     win_odds  \
# count      3358.000000  3350.000000  3358.000000  3358.000000
# mean         54.533353    69.782776     8.106015    62.643895
# std           1.624742     1.363750     4.476073    93.612983
# min          50.000000    66.800000     1.000000     1.400000
# 25%          54.000000    68.900000     4.000000     9.200000
# 50%          54.000000    69.600000     8.000000    24.050000
# 75%          56.000000    70.500000    12.000000    71.300000
# max          59.000000    85.800000    16.000000   732.300000
#
#        final_3_furlong  horse_weight  gain_and_loss_weight
# count      3350.000000   3358.000000           3358.000000
# mean         35.144716    463.316260              0.914532
# std           1.115313     31.045942              6.173552
# min          32.400000    362.000000            -26.000000
# 25%          34.400000    442.000000             -2.000000
# 50%          35.100000    464.000000              0.000000
# 75%          35.800000    486.000000              4.000000
# max          52.300000    564.000000             32.000000

# %% [markdown]
# ### Standardization

# %%
data_st = data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data_st)
data_st = pd.DataFrame(df_scaled, columns=data_st.columns)
data_st.head()
# Out:
#    race_track_id       kai     nichi   race_no  grade_id  num_of_horses  \
# 0            0.0  1.218984 -1.156584  1.887161  0.027672      -0.134469
# 1            0.0  1.218984 -1.156584  1.887161  0.027672      -0.134469
# 2            0.0  1.218984 -1.156584  1.887161  0.027672      -0.134469
# 3            0.0  1.218984 -1.156584  1.887161  0.027672      -0.134469
# 4            0.0  1.218984 -1.156584  1.887161  0.027672      -0.134469
#
#      result  bracket_number  horse_number       age  weight_to_carry  \
# 0 -1.585821        0.165069      0.199755 -0.486743         0.902830
# 1 -1.362109       -0.714774     -0.694019 -0.486743        -0.328318
# 2 -1.138396        0.604991      0.646642  0.074164         1.518404
# 3 -0.914684        0.165069     -0.023688  0.635071         1.518404
# 4 -0.690971       -1.154696     -1.364349  1.195979         0.287256
#
#        time     ninki  win_odds  final_3_furlong  horse_weight  \
# 0 -1.747485 -0.470575 -0.554962        -1.205865      0.150887
# 1 -1.600808 -1.587792 -0.639364        -0.757493      0.215318
# 2 -1.454132 -1.364349 -0.620133        -1.026516      1.052911
# 3 -1.380794 -1.140905 -0.592355        -0.578145      2.470376
# 4 -1.380794 -0.023688 -0.484448        -0.936842      1.761644
#
#    gain_and_loss_weight
# 0              1.147884
# 1             -0.148159
# 2              0.175852
# 3              0.175852
# 4              0.499863

# %% [markdown]
# ### Correlation

# %%
corr_matrix = data.corr()
corr_y = pd.DataFrame({"features":data.columns, "corr_y":corr_matrix["result"]}, index=None)
corr_y = corr_y.reset_index(drop=True)
corr_y.style.background_gradient()
# Out:
# <style type="text/css">
# #T_9578c_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9578c_row1_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_9578c_row2_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_9578c_row3_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9578c_row4_col1, #T_9578c_row7_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9578c_row5_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_9578c_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9578c_row8_col1, #T_9578c_row9_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_9578c_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9578c_row11_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_9578c_row12_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_9578c_row13_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_9578c_row14_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_9578c_row15_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9578c_row16_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# </style>
# <table id="T_9578c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >features</th>
#       <th class="col_heading level0 col1" >corr_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9578c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9578c_row0_col0" class="data row0 col0" >race_track_id</td>
#       <td id="T_9578c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9578c_row1_col0" class="data row1 col0" >kai</td>
#       <td id="T_9578c_row1_col1" class="data row1 col1" >0.006991</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9578c_row2_col0" class="data row2 col0" >nichi</td>
#       <td id="T_9578c_row2_col1" class="data row2 col1" >0.017119</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9578c_row3_col0" class="data row3 col0" >race_no</td>
#       <td id="T_9578c_row3_col1" class="data row3 col1" >-0.032299</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9578c_row4_col0" class="data row4 col0" >grade_id</td>
#       <td id="T_9578c_row4_col1" class="data row4 col1" >0.031521</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9578c_row5_col0" class="data row5 col0" >num_of_horses</td>
#       <td id="T_9578c_row5_col1" class="data row5 col1" >0.176811</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9578c_row6_col0" class="data row6 col0" >result</td>
#       <td id="T_9578c_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9578c_row7_col0" class="data row7 col0" >bracket_number</td>
#       <td id="T_9578c_row7_col1" class="data row7 col1" >0.033867</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9578c_row8_col0" class="data row8 col0" >horse_number</td>
#       <td id="T_9578c_row8_col1" class="data row8 col1" >0.078440</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9578c_row9_col0" class="data row9 col0" >age</td>
#       <td id="T_9578c_row9_col1" class="data row9 col1" >0.079192</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9578c_row10_col0" class="data row10 col0" >weight_to_carry</td>
#       <td id="T_9578c_row10_col1" class="data row10 col1" >-0.074334</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9578c_row11_col0" class="data row11 col0" >time</td>
#       <td id="T_9578c_row11_col1" class="data row11 col1" >0.410496</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9578c_row12_col0" class="data row12 col0" >ninki</td>
#       <td id="T_9578c_row12_col1" class="data row12 col1" >0.545583</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9578c_row13_col0" class="data row13 col0" >win_odds</td>
#       <td id="T_9578c_row13_col1" class="data row13 col1" >0.442613</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9578c_row14_col0" class="data row14 col0" >final_3_furlong</td>
#       <td id="T_9578c_row14_col1" class="data row14 col1" >0.346037</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9578c_row15_col0" class="data row15 col0" >horse_weight</td>
#       <td id="T_9578c_row15_col1" class="data row15 col1" >-0.054454</td>
#     </tr>
#     <tr>
#       <th id="T_9578c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9578c_row16_col0" class="data row16 col0" >gain_and_loss_weight</td>
#       <td id="T_9578c_row16_col1" class="data row16 col1" >0.012815</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.corr()
# Out:
#                       race_track_id       kai     nichi   race_no  grade_id  \
# race_track_id                   NaN       NaN       NaN       NaN       NaN
# kai                             NaN  1.000000  0.157150 -0.037505  0.390126
# nichi                           NaN  0.157150  1.000000  0.032417 -0.074144
# race_no                         NaN -0.037505  0.032417  1.000000  0.006865
# grade_id                        NaN  0.390126 -0.074144  0.006865  1.000000
# num_of_horses                   NaN  0.047483  0.097686 -0.195629  0.185049
# result                          NaN  0.006991  0.017119 -0.032299  0.031521
# bracket_number                  NaN -0.004941 -0.009857  0.017586 -0.014826
# horse_number                    NaN  0.008365  0.017209 -0.034463  0.032599
# age                             NaN -0.414361 -0.061365 -0.315655 -0.606245
# weight_to_carry                 NaN -0.203890 -0.022780 -0.001593 -0.347354
# time                            NaN  0.139656  0.033187  0.204551  0.523715
# ninki                           NaN  0.008365  0.017209 -0.034463  0.032599
# win_odds                        NaN  0.065716  0.026398  0.061117  0.087523
# final_3_furlong                 NaN  0.070690  0.015967  0.173990  0.357795
# horse_weight                    NaN -0.227808 -0.001781 -0.146564 -0.459152
# gain_and_loss_weight            NaN  0.017500 -0.026932  0.000306  0.040832
#
#                       num_of_horses    result  bracket_number  horse_number  \
# race_track_id                   NaN       NaN             NaN           NaN
# kai                        0.047483  0.006991       -0.004941      0.008365
# nichi                      0.097686  0.017119       -0.009857      0.017209
# race_no                   -0.195629 -0.032299        0.017586     -0.034463
# grade_id                   0.185049  0.031521       -0.014826      0.032599
# num_of_horses              1.000000  0.176811       -0.083652      0.176163
# result                     0.176811  1.000000        0.033867      0.078440
# bracket_number            -0.083652  0.033867        1.000000      0.953164
# horse_number               0.176163  0.078440        0.953164      1.000000
# age                       -0.024138  0.079192        0.003998     -0.003692
# weight_to_carry           -0.098557 -0.074334        0.011695     -0.014741
# time                       0.044845  0.410496        0.013868      0.024649
# ninki                      0.176163  0.545583        0.041057      0.083860
# win_odds                   0.060132  0.442613        0.048141      0.062737
# final_3_furlong            0.059799  0.346037        0.002444      0.017045
# horse_weight              -0.047366 -0.054454       -0.007527     -0.018608
# gain_and_loss_weight       0.047757  0.012815       -0.006700      0.007055
#
#                            age  weight_to_carry      time     ninki  win_odds  \
# race_track_id              NaN              NaN       NaN       NaN       NaN
# kai                  -0.414361        -0.203890  0.139656  0.008365  0.065716
# nichi                -0.061365        -0.022780  0.033187  0.017209  0.026398
# race_no              -0.315655        -0.001593  0.204551 -0.034463  0.061117
# grade_id             -0.606245        -0.347354  0.523715  0.032599  0.087523
# num_of_horses        -0.024138        -0.098557  0.044845  0.176163  0.060132
# result                0.079192        -0.074334  0.410496  0.545583  0.442613
# bracket_number        0.003998         0.011695  0.013868  0.041057  0.048141
# horse_number         -0.003692        -0.014741  0.024649  0.083860  0.062737
# age                   1.000000         0.389680 -0.424393  0.167658 -0.006643
# weight_to_carry       0.389680         1.000000 -0.221058 -0.089412 -0.102682
# time                 -0.424393        -0.221058  1.000000  0.237541  0.279889
# ninki                 0.167658        -0.089412  0.237541  1.000000  0.692944
# win_odds             -0.006643        -0.102682  0.279889  0.692944  1.000000
# final_3_furlong      -0.346966        -0.199038  0.793193  0.155605  0.193408
# horse_weight          0.488648         0.432619 -0.323720 -0.101180 -0.140551
# gain_and_loss_weight -0.000377        -0.000384  0.005836  0.020681  0.009634
#
#                       final_3_furlong  horse_weight  gain_and_loss_weight
# race_track_id                     NaN           NaN                   NaN
# kai                          0.070690     -0.227808              0.017500
# nichi                        0.015967     -0.001781             -0.026932
# race_no                      0.173990     -0.146564              0.000306
# grade_id                     0.357795     -0.459152              0.040832
# num_of_horses                0.059799     -0.047366              0.047757
# result                       0.346037     -0.054454              0.012815
# bracket_number               0.002444     -0.007527             -0.006700
# horse_number                 0.017045     -0.018608              0.007055
# age                         -0.346966      0.488648             -0.000377
# weight_to_carry             -0.199038      0.432619             -0.000384
# time                         0.793193     -0.323720              0.005836
# ninki                        0.155605     -0.101180              0.020681
# win_odds                     0.193408     -0.140551              0.009634
# final_3_furlong              1.000000     -0.241121              0.041880
# horse_weight                -0.241121      1.000000              0.075606
# gain_and_loss_weight         0.041880      0.075606              1.000000

# %% [markdown]
# ### Model

# %%
from sklearn.model_selection import train_test_split
train_X = data_st[["bracket_number", "horse_number", "weight_to_carry", "win_odds", "horse_weight"]]
train_y = data_st["result"]
(train_X, test_X, train_y, test_y) = train_test_split(train_X, train_y, test_size=0.25, random_state=666)

# %% [markdown]
# ### 重回帰

# %%
from sklearn.linear_model import LinearRegression
model_LR = LinearRegression()
model_LR.fit(train_X, train_y)
LR_y_test_pred = model_LR.predict(test_X)
LR_y_train_pred = model_LR.predict(train_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-493dd73efa72> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 model_LR = LinearRegression()
# ----> 3 model_LR.fit(train_X, train_y)
#       4 LR_y_test_pred = model_LR.predict(test_X)
#       5 LR_y_train_pred = model_LR.predict(train_X)
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     821                     estimator=estimator)
#     822     if multi_output:
# --> 823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#     824                         ensure_2d=False, dtype=None)
#     825     else:
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.metrics import mean_squared_error
print("LR RMSE train data: ", np.sqrt(mean_squared_error(train_y, LR_y_train_pred)))
print("LR RMSE train data: ", np.sqrt(mean_squared_error(test_y, LR_y_test_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-f965bf454032> in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 print("LR RMSE train data: ", np.sqrt(mean_squared_error(train_y, LR_y_train_pred)))
#       3 print("LR RMSE train data: ", np.sqrt(mean_squared_error(test_y, LR_y_test_pred)))
#
# NameError: name 'train_y' is not defined
