# %% [markdown]
# ### Import

# %%
from sqlalchemy import create_engine
import os
import yaml
from pathlib import Path

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Config

# %%
base = Path().resolve()
db_conf_file = os.path.normpath(os.path.join(base, "../conf/db_connection.yaml"))
with open(db_conf_file, "r", encoding="utf-8") as l_file:
    db_conf_all = yaml.safe_load(l_file)

# %% [markdown]
# ### Create Engine

# %%
ora_conf = db_conf_all["oracle"]
engine = create_engine(f"oracle://{ora_conf['username']}:{ora_conf['password']}@{ora_conf['dsn']}/?encoding=UTF-8&nencoding=UTF-8")

# %% [markdown]
# ### Condition

# %%
c_cource_id = "05_t1800"

# %% [markdown]
# ### Query

# %%
from sqlalchemy.sql import select
from sqlalchemy.sql import join

from model.race import Race
from keibaai.model.race import RaceUma

query_statement = (
    select(
        join(Race, RaceUma, Race.id == RaceUma.race_id)
        ).where(
            Race.course_id == c_cource_id
        )
)
print(query_statement)
# Out:
# SELECT races.id, races.name, races.race_track_id, races.kai, races.nichi, races.race_no, races.course_id, races.grade_id, races.is_win5, races.condition, races.handicap, races.race_date, races.race_start, races.weather, races.going, races.num_of_horses, races.race_data, races.corner_order_1, races.corner_order_2, races.corner_order_3, races.corner_order_4, races.pace, race_uma.race_id, race_uma.uma_id, race_uma.result, race_uma.bracket_number, race_uma.horse_number, race_uma.gender, race_uma.age, race_uma.weight_to_carry, race_uma.jockey_id, race_uma.time, race_uma.margin, race_uma.ninki, race_uma.win_odds, race_uma.final_3_furlong, race_uma.corner_order, race_uma.trainer_id, race_uma.horse_weight, race_uma.gain_and_loss_weight, race_uma.is_excluded, race_uma.is_demoted
# FROM races JOIN race_uma ON races.id = race_uma.race_id
# WHERE races.course_id = :course_id_1

# %%
query_statement = (
    select(
        Race.race_track_id, Race.kai, Race.nichi, Race.race_no, Race.grade_id, Race.num_of_horses, RaceUma.result, RaceUma.bracket_number, RaceUma.horse_number, RaceUma.age, RaceUma.weight_to_carry, RaceUma.time, RaceUma.ninki, RaceUma.win_odds, RaceUma.final_3_furlong, RaceUma.horse_weight, RaceUma.gain_and_loss_weight
    ).select_from(
        join(Race, RaceUma, Race.id == RaceUma.race_id)
    ).where(
        Race.course_id == c_cource_id
    )
)
print(query_statement)
# Out:
# SELECT races.race_track_id, races.kai, races.nichi, races.race_no, races.grade_id, races.num_of_horses, race_uma.result, race_uma.bracket_number, race_uma.horse_number, race_uma.age, race_uma.weight_to_carry, race_uma.time, race_uma.ninki, race_uma.win_odds, race_uma.final_3_furlong, race_uma.horse_weight, race_uma.gain_and_loss_weight
# FROM races JOIN race_uma ON races.id = race_uma.race_id
# WHERE races.course_id = :course_id_1

# %% [markdown]
# ### Read Data

# %%
data = pd.read_sql_query(sql=query_statement, con=engine)
data
# Out:
#       race_track_id  kai  nichi  race_no  grade_id  num_of_horses  result  \
# 0                50   10     30        6        31             13     1.0
# 1                50   10     30        6        31             13     2.0
# 2                50   10     30        6        31             13     3.0
# 3                50   10     30        6        31             13     3.0
# 4                50   10     30        6        31             13     5.0
# ...             ...  ...    ...      ...       ...            ...     ...
# 5036             50   30     80        9        17              9     5.0
# 5037             50   30     80        9        17              9     6.0
# 5038             50   30     80        9        17              9     7.0
# 5039             50   30     80        9        17              9     8.0
# 5040             50   30     80        9        17              9     9.0
#
#       bracket_number  horse_number  age  weight_to_carry   time  ninki  \
# 0                  6             8    3             56.0  107.6      2
# 1                  8            13    3             56.0  108.0      3
# 2                  3             3    3             56.0  108.2      4
# 3                  5             6    3             56.0  108.2      1
# 4                  4             4    3             54.0  108.6     11
# ...              ...           ...  ...              ...    ...    ...
# 5036               1             1    5             55.0  107.0      4
# 5037               8             8    4             55.0  107.5      8
# 5038               4             4    6             57.0  108.3      6
# 5039               8             9   11             57.0  108.9      7
# 5040               5             5    7             57.0  109.3      9
#
#       win_odds  final_3_furlong  horse_weight  gain_and_loss_weight
# 0          3.2             34.9           452                   0.0
# 1          5.1             35.1           478                   0.0
# 2          5.7             34.9           486                   0.0
# 3          2.7             35.0           490                   0.0
# 4        130.8             35.2           452                   0.0
# ...        ...              ...           ...                   ...
# 5036      14.9             35.2           490                   2.0
# 5037     142.3             34.4           422                   0.0
# 5038      46.6             35.7           468                  -2.0
# 5039      80.0             36.6           484                  -6.0
# 5040     233.9             36.7           490                   0.0
#
# [5041 rows x 17 columns]

# %% [markdown]
# ### Describe

# %%
data.describe()
# Out:
#        race_track_id          kai        nichi      race_no     grade_id  \
# count         5041.0  5041.000000  5041.000000  5041.000000  5041.000000
# mean            50.0    26.969252    46.228923     4.614164    20.442968
# std              0.0    14.339964    24.910084     2.726507    10.894933
# min             50.0    10.000000     0.000000     0.000000     2.000000
# 25%             50.0    10.000000    21.000000     2.000000     9.000000
# 50%             50.0    21.000000    41.000000     5.000000    30.000000
# 75%             50.0    40.000000    70.000000     6.000000    30.000000
# max             50.0    50.000000    91.000000     9.000000    31.000000
#
#        num_of_horses       result  bracket_number  horse_number          age  \
# count    5041.000000  5032.000000     5041.000000   5041.000000  5041.000000
# mean       14.054553     7.514706        4.804007      7.527276     3.415195
# std         2.911526     4.375827        2.285755      4.382516     1.310670
# min         6.000000     1.000000        1.000000      1.000000     2.000000
# 25%        12.000000     4.000000        3.000000      4.000000     3.000000
# 50%        15.000000     7.000000        5.000000      7.000000     3.000000
# 75%        16.000000    11.000000        7.000000     11.000000     4.000000
# max        18.000000    18.000000        8.000000     18.000000    11.000000
#
#        weight_to_carry         time        ninki     win_odds  \
# count      5041.000000  5032.000000  5041.000000  5041.000000
# mean         54.740230   109.342428     7.527276    74.707181
# std           1.390913     2.264415     4.382516   108.165675
# min          49.000000   104.300000     1.000000     1.100000
# 25%          54.000000   107.800000     4.000000     7.900000
# 50%          55.000000   109.100000     7.000000    26.100000
# 75%          56.000000   110.600000    11.000000    94.600000
# max          59.000000   127.700000    18.000000   929.400000
#
#        final_3_furlong  horse_weight  gain_and_loss_weight
# count      5032.000000   5041.000000           5039.000000
# mean         35.058963    465.397739              0.404247
# std           1.345381     29.059147              5.858690
# min          32.300000    368.000000            -34.000000
# 25%          34.200000    444.000000             -2.000000
# 50%          34.800000    466.000000              0.000000
# 75%          35.600000    486.000000              2.000000
# max          48.100000    566.000000             34.000000

# %% [markdown]
# ### Standardization

# %%
data_st = data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data_st)
data_st = pd.DataFrame(df_scaled, columns=data_st.columns)
data_st.head()
# Out:
#    race_track_id       kai     nichi   race_no  grade_id  num_of_horses  \
# 0            0.0 -1.183471 -0.651565  0.508333  0.969082      -0.362235
# 1            0.0 -1.183471 -0.651565  0.508333  0.969082      -0.362235
# 2            0.0 -1.183471 -0.651565  0.508333  0.969082      -0.362235
# 3            0.0 -1.183471 -0.651565  0.508333  0.969082      -0.362235
# 4            0.0 -1.183471 -0.651565  0.508333  0.969082      -0.362235
#
#      result  bracket_number  horse_number       age  weight_to_carry  \
# 0 -1.488942        0.523290      0.107877 -0.316812         0.905804
# 1 -1.260391        1.398361      1.248887 -0.316812         0.905804
# 2 -1.031840       -0.789317     -1.033134 -0.316812         0.905804
# 3 -1.031840        0.085754     -0.348528 -0.316812         0.905804
# 4 -0.574738       -0.351782     -0.804932 -0.316812        -0.532243
#
#        time     ninki  win_odds  final_3_furlong  horse_weight  \
# 0 -0.769559 -1.261336 -0.661155        -0.118166     -0.461096
# 1 -0.592896 -1.033134 -0.643588         0.030505      0.433719
# 2 -0.504564 -0.804932 -0.638040        -0.118166      0.709047
# 3 -0.504564 -1.489538 -0.665778        -0.043830      0.846711
# 4 -0.327900  0.792483  0.518634         0.104841     -0.461096
#
#    gain_and_loss_weight
# 0             -0.069006
# 1             -0.069006
# 2             -0.069006
# 3             -0.069006
# 4             -0.069006

# %% [markdown]
# ### Correlation

# %%
corr_matrix = data.corr()
corr_y = pd.DataFrame({"features":data.columns, "corr_y":corr_matrix["result"]}, index=None)
corr_y = corr_y.reset_index(drop=True)
corr_y.style.background_gradient()
# Out:
# <style type="text/css">
# #T_3c8f3_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3c8f3_row1_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_3c8f3_row2_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3c8f3_row3_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_3c8f3_row4_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_3c8f3_row5_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_3c8f3_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3c8f3_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_3c8f3_row8_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_3c8f3_row9_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_3c8f3_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3c8f3_row11_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_3c8f3_row12_col1 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_3c8f3_row13_col1 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_3c8f3_row14_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_3c8f3_row15_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_3c8f3_row16_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# </style>
# <table id="T_3c8f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >features</th>
#       <th class="col_heading level0 col1" >corr_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c8f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c8f3_row0_col0" class="data row0 col0" >race_track_id</td>
#       <td id="T_3c8f3_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c8f3_row1_col0" class="data row1 col0" >kai</td>
#       <td id="T_3c8f3_row1_col1" class="data row1 col1" >-0.078411</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c8f3_row2_col0" class="data row2 col0" >nichi</td>
#       <td id="T_3c8f3_row2_col1" class="data row2 col1" >-0.017852</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c8f3_row3_col0" class="data row3 col0" >race_no</td>
#       <td id="T_3c8f3_row3_col1" class="data row3 col1" >-0.044456</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c8f3_row4_col0" class="data row4 col0" >grade_id</td>
#       <td id="T_3c8f3_row4_col1" class="data row4 col1" >0.108027</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c8f3_row5_col0" class="data row5 col0" >num_of_horses</td>
#       <td id="T_3c8f3_row5_col1" class="data row5 col1" >0.331989</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c8f3_row6_col0" class="data row6 col0" >result</td>
#       <td id="T_3c8f3_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c8f3_row7_col0" class="data row7 col0" >bracket_number</td>
#       <td id="T_3c8f3_row7_col1" class="data row7 col1" >0.030716</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c8f3_row8_col0" class="data row8 col0" >horse_number</td>
#       <td id="T_3c8f3_row8_col1" class="data row8 col1" >0.160173</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c8f3_row9_col0" class="data row9 col0" >age</td>
#       <td id="T_3c8f3_row9_col1" class="data row9 col1" >0.047859</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3c8f3_row10_col0" class="data row10 col0" >weight_to_carry</td>
#       <td id="T_3c8f3_row10_col1" class="data row10 col1" >-0.135278</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3c8f3_row11_col0" class="data row11 col0" >time</td>
#       <td id="T_3c8f3_row11_col1" class="data row11 col1" >0.355406</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3c8f3_row12_col0" class="data row12 col0" >ninki</td>
#       <td id="T_3c8f3_row12_col1" class="data row12 col1" >0.651365</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3c8f3_row13_col0" class="data row13 col0" >win_odds</td>
#       <td id="T_3c8f3_row13_col1" class="data row13 col1" >0.524571</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3c8f3_row14_col0" class="data row14 col0" >final_3_furlong</td>
#       <td id="T_3c8f3_row14_col1" class="data row14 col1" >0.509368</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3c8f3_row15_col0" class="data row15 col0" >horse_weight</td>
#       <td id="T_3c8f3_row15_col1" class="data row15 col1" >-0.112877</td>
#     </tr>
#     <tr>
#       <th id="T_3c8f3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3c8f3_row16_col0" class="data row16 col0" >gain_and_loss_weight</td>
#       <td id="T_3c8f3_row16_col1" class="data row16 col1" >-0.004298</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.corr()
# Out:
#                       race_track_id       kai     nichi   race_no  grade_id  \
# race_track_id                   NaN       NaN       NaN       NaN       NaN
# kai                             NaN  1.000000  0.151430 -0.228419  0.020595
# nichi                           NaN  0.151430  1.000000 -0.071234 -0.002993
# race_no                         NaN -0.228419 -0.071234  1.000000  0.027717
# grade_id                        NaN  0.020595 -0.002993  0.027717  1.000000
# num_of_horses                   NaN -0.237996 -0.053459 -0.135042  0.330394
# result                          NaN -0.078411 -0.017852 -0.044456  0.108027
# bracket_number                  NaN  0.038545 -0.001554 -0.001280 -0.031370
# horse_number                    NaN -0.079056 -0.017758 -0.044858  0.109749
# age                             NaN -0.243307 -0.062614  0.010469 -0.623794
# weight_to_carry                 NaN -0.089397 -0.091435  0.029835 -0.262511
# time                            NaN  0.103206  0.137310  0.039336  0.527136
# ninki                           NaN -0.079056 -0.017758 -0.044858  0.109749
# win_odds                        NaN -0.024949 -0.033367 -0.023138  0.168581
# final_3_furlong                 NaN  0.001994  0.085944 -0.043295  0.288315
# horse_weight                    NaN  0.060722 -0.006051 -0.022837 -0.199261
# gain_and_loss_weight            NaN  0.012276  0.029378  0.025403 -0.040507
#
#                       num_of_horses    result  bracket_number  horse_number  \
# race_track_id                   NaN       NaN             NaN           NaN
# kai                       -0.237996 -0.078411        0.038545     -0.079056
# nichi                     -0.053459 -0.017852       -0.001554     -0.017758
# race_no                   -0.135042 -0.044456       -0.001280     -0.044858
# grade_id                   0.330394  0.108027       -0.031370      0.109749
# num_of_horses              1.000000  0.331989       -0.047497      0.332175
# result                     0.331989  1.000000        0.030716      0.160173
# bracket_number            -0.047497  0.030716        1.000000      0.892597
# horse_number               0.332175  0.160173        0.892597      1.000000
# age                       -0.063130  0.047859        0.013459     -0.020262
# weight_to_carry           -0.186673 -0.135278        0.015312     -0.057337
# time                       0.080374  0.355406        0.004374      0.046948
# ninki                      0.332175  0.651365        0.018835      0.142752
# win_odds                   0.183730  0.524571        0.030195      0.102790
# final_3_furlong            0.153121  0.509368       -0.000900      0.064353
# horse_weight              -0.138767 -0.112877       -0.002536     -0.057242
# gain_and_loss_weight      -0.009535 -0.004298        0.005945      0.005181
#
#                            age  weight_to_carry      time     ninki  win_odds  \
# race_track_id              NaN              NaN       NaN       NaN       NaN
# kai                  -0.243307        -0.089397  0.103206 -0.079056 -0.024949
# nichi                -0.062614        -0.091435  0.137310 -0.017758 -0.033367
# race_no               0.010469         0.029835  0.039336 -0.044858 -0.023138
# grade_id             -0.623794        -0.262511  0.527136  0.109749  0.168581
# num_of_horses        -0.063130        -0.186673  0.080374  0.332175  0.183730
# result                0.047859        -0.135278  0.355406  0.651365  0.524571
# bracket_number        0.013459         0.015312  0.004374  0.018835  0.030195
# horse_number         -0.020262        -0.057337  0.046948  0.142752  0.102790
# age                   1.000000         0.349334 -0.456724  0.098149 -0.030393
# weight_to_carry       0.349334         1.000000 -0.179249 -0.190384 -0.175791
# time                 -0.456724        -0.179249  1.000000  0.239757  0.238895
# ninki                 0.098149        -0.190384  0.239757  1.000000  0.747593
# win_odds             -0.030393        -0.175791  0.238895  0.747593  1.000000
# final_3_furlong      -0.140111        -0.110118  0.525009  0.343868  0.315788
# horse_weight          0.195087         0.361304 -0.101755 -0.179584 -0.161588
# gain_and_loss_weight  0.003053         0.010538 -0.004803 -0.044554 -0.057584
#
#                       final_3_furlong  horse_weight  gain_and_loss_weight
# race_track_id                     NaN           NaN                   NaN
# kai                          0.001994      0.060722              0.012276
# nichi                        0.085944     -0.006051              0.029378
# race_no                     -0.043295     -0.022837              0.025403
# grade_id                     0.288315     -0.199261             -0.040507
# num_of_horses                0.153121     -0.138767             -0.009535
# result                       0.509368     -0.112877             -0.004298
# bracket_number              -0.000900     -0.002536              0.005945
# horse_number                 0.064353     -0.057242              0.005181
# age                         -0.140111      0.195087              0.003053
# weight_to_carry             -0.110118      0.361304              0.010538
# time                         0.525009     -0.101755             -0.004803
# ninki                        0.343868     -0.179584             -0.044554
# win_odds                     0.315788     -0.161588             -0.057584
# final_3_furlong              1.000000     -0.049204              0.007519
# horse_weight                -0.049204      1.000000              0.119278
# gain_and_loss_weight         0.007519      0.119278              1.000000

# %% [markdown]
# ### Model

# %%
from sklearn.model_selection import train_test_split
train_X = data_st[["bracket_number", "horse_number", "weight_to_carry", "win_odds", "horse_weight"]]
train_y = data_st["result"]
(train_X, test_X, train_y, test_y) = train_test_split(train_X, train_y, test_size=0.25, random_state=666)

# %% [markdown]
# ### 重回帰

# %%
from sklearn.linear_model import LinearRegression
model_LR = LinearRegression()
model_LR.fit(train_X, train_y)
LR_y_test_pred = model_LR.predict(test_X)
LR_y_train_pred = model_LR.predict(train_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-493dd73efa72> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 model_LR = LinearRegression()
# ----> 3 model_LR.fit(train_X, train_y)
#       4 LR_y_test_pred = model_LR.predict(test_X)
#       5 LR_y_train_pred = model_LR.predict(train_X)
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     821                     estimator=estimator)
#     822     if multi_output:
# --> 823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#     824                         ensure_2d=False, dtype=None)
#     825     else:
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# c:\Users\shun8\OneDrive\python\keibaai\.venv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# ### 予測精度算出

# %%
from sklearn.metrics import mean_squared_error
print("LR RMSE train data: ", np.sqrt(mean_squared_error(train_y, LR_y_train_pred)))
print("LR RMSE train data: ", np.sqrt(mean_squared_error(test_y, LR_y_test_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-f965bf454032> in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 print("LR RMSE train data: ", np.sqrt(mean_squared_error(train_y, LR_y_train_pred)))
#       3 print("LR RMSE train data: ", np.sqrt(mean_squared_error(test_y, LR_y_test_pred)))
#
# NameError: name 'train_y' is not defined

# %%
from sklearn.metrics import r2_score
print("LR r^2 train data: ", r2_score(train_y, LR_y_train_pred))
print("LR r^2 train data: ", r2_score(test_y, LR_y_test_pred))

# %%
from sklearn.metrics import mean_absolute_error
print("LR MAE train data: ", mean_absolute_error(train_y, LR_y_train_pred))
print("LR MAE train data: ", mean_absolute_error(test_y, LR_y_test_pred))

# %%
flg, ax = plt.subplots(figsize=(10, 6.0))
plt.xticks(rotation=45, fontsize=9)

plt.scatter(train_y, LR_y_train_pred)
plt.plot(train_y, train_y, "red")

plt.legend(fontsize=14)

# %%
flg, ax = plt.subplots(figsize=(10, 6.0))
plt.xticks(rotation=45, fontsize=9)

plt.scatter(test_y, LR_y_test_pred)
plt.plot(test_y, test_y, "red")

plt.legend(fontsize=14)
