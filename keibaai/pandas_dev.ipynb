# %%
import pandas as pd

# %%
dfs = pd.read_html("https://race.netkeiba.com/race/shutuba.html?race_id=202105050812")

# %%
print(dfs[0])
# Out:
#     枠  馬番   印         馬名  性齢    斤量     騎手       厩舎   馬体重(増減)  \
#     枠  馬番   印         馬名  性齢    斤量     騎手       厩舎   馬体重(増減)
# 0   1   1 NaN  ムイトオブリガード  牡7  57.0    柴田善     栗東角田   490(-2)
# 1   1   2 NaN     コントレイル  牡4  57.0     福永     栗東矢作   456(-8)
# 2   2   3 NaN       ブルーム  牡5  57.0    ムーア  海外Ａオブライ  464(前計不)
# 3   2   4 NaN    シャフリヤール  牡3  55.0     川田    栗東藤原英   446(-6)
# 4   3   5 NaN        キセキ  牡7  57.0    和田竜     栗東辻野   512(+6)
# 5   3   6 NaN  グランドグローリー  牝5  55.0  Ｃデムーロ  海外ビエトリー  466(前計不)
# 6   4   7 NaN     オーソリティ  牡4  57.0   ルメール     美浦木村   520(+2)
# 7   4   8 NaN   ウインドジャマー  セ4  57.0    北村宏    美浦藤沢和   508(-2)
# 8   5   9 NaN    アリストテレス  牡4  57.0    横山武     栗東音無   480(+8)
# 9   5  10 NaN   ロードマイウェイ  牡5  57.0     三浦    栗東杉山晴   474(+4)
# 10  6  11 NaN  シャドウディーヴァ  牝5  55.0    横山典    美浦斎藤誠   478(-4)
# 11  6  12 NaN   サンレイポケット  牡6  57.0    鮫島駿    栗東高橋忠   474(+2)
# 12  7  13 NaN      モズベッロ  牡5  57.0     池添     栗東森田   488(+6)
# ...

# %%
dfs = pd.read_html("https://race.netkeiba.com/race/result.html?race_id=202105050812")

# %%
dfs[0]
# Out:
#     着順  枠  馬番         馬名  性齢    斤量   騎手     タイム     着差  人気  単勝オッズ   後3F  \
# 0    1  1   2     コントレイル  牡4  57.0   福永  2:24.7    NaN   1    1.6  33.7
# 1    2  4   7     オーソリティ  牡4  57.0  ルメー  2:25.0      2   3    7.1  34.4
# 2    3  2   4    シャフリヤール  牡3  55.0   川田  2:25.2  1.1/2   2    3.7  34.4
# 3    4  6  12   サンレイポケット  牡6  57.0  鮫島駿  2:25.4    3/4  10   70.5  34.5
# 4    5  3   6  グランドグローリー  牝5  55.0  Ｃデム  2:25.5    3/4   8   56.6  34.2
# 5    6  7  14   ユーバーレーベン  牝3  53.0  Ｍデム  2:25.5     クビ   5   25.5  34.2
# 6    7  6  11  シャドウディーヴァ  牝5  55.0  横山典  2:25.6    1/2  11   76.4  34.8
# 7    8  8  18       ジャパン  牡5  57.0   武豊  2:25.7     クビ   9   59.3  34.3
# 8    9  5   9    アリストテレス  牡4  57.0  横山武  2:25.8      1   4   20.5  35.3
# 9   10  3   5        キセキ  牡7  57.0  和田竜  2:26.0      1   7   37.4  36.6
# 10  11  2   3       ブルーム  牡5  57.0  ムーア  2:26.1    1/2   6   29.0  34.8
# 11  12  8  16  ユーキャンスマイル  牡6  57.0  藤岡佑  2:26.2      1  14  240.1  34.7
# ...
